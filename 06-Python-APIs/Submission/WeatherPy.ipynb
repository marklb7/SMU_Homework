# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
from scipy.stats import linregress
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 625

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#init lists to hold parsed data
cities_found = []
lats = []
longs = []
temps = []
humids = []
speeds = []
cloudiness = []

for i in range(len(cities)):
    #get the city
    city = cities[i]
    
    #create the url
    units = "imperial"
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&units={units}&appid={weather_api_key}"

    #make the request
    response = requests.get(url)
    
    #error check
    if response.status_code == 200:
        data = response.json()
        
        try:
            #extract the data
            city_name = data["name"]
            lat = data["coord"]["lat"]
            long = data["coord"]["lon"]
            temp = data["main"]["temp"]
            humidity = data["main"]["humidity"]
            speed = data["wind"]["speed"]
            clouds = data["clouds"]["all"]

            #save the data
            cities_found.append(city_name)
            lats.append(lat)
            longs.append(long)
            temps.append(temp)
            humids.append(humidity)
            speeds.append(speed)
            cloudiness.append(clouds)
            
            #Prints status
            print(f"Processing Record {i} of {len(cities)} | {city} ")
            
        except Exception as e:
            print(f"Through exception for city {city}: {e}")
    
    elif response.status_code == 404:
        print(f"Missing data in OpenWeatherAPI for {city}")
    else:
        print(response.status_code)
        print("The API is broken.")
    
    #sleep for requests
    time.sleep(1)
        
# make the dataframe
df = pd.DataFrame()
df["City"] = cities_found
df["Latitude"] = lats
df["Longitude"] = longs
df["Temperature"] = temps
df["Humidity"] = humids
df["Wind Speed"] = speeds
df["Cloudiness"] = cloudiness

df.head(10)
# Out:
# Processing Record 0 of 625 | qaanaaq
# Processing Record 1 of 625 | mataura
# Missing data in OpenWeatherAPI for yomitan
# Processing Record 3 of 625 | busselton
# Processing Record 4 of 625 | wonthaggi
# Processing Record 5 of 625 | wanning
# Processing Record 6 of 625 | pangnirtung
# Processing Record 7 of 625 | saint-augustin
# Processing Record 8 of 625 | punta arenas
# Processing Record 9 of 625 | cape town
# Processing Record 10 of 625 | rikitea
# Processing Record 11 of 625 | port hardy
# Processing Record 12 of 625 | perth
# Processing Record 13 of 625 | umtata
# Processing Record 14 of 625 | hermanus
# Processing Record 15 of 625 | ushuaia
# Processing Record 16 of 625 | saskylakh
# Processing Record 17 of 625 | sembakung
# Processing Record 18 of 625 | kruisfontein
# Processing Record 19 of 625 | porto velho
# Processing Record 20 of 625 | bluff
# Processing Record 21 of 625 | salalah
# Processing Record 22 of 625 | narsaq
# Processing Record 23 of 625 | sao filipe
# Processing Record 24 of 625 | sanchor
# Processing Record 25 of 625 | jinxiang
# Processing Record 26 of 625 | novoagansk
# Processing Record 27 of 625 | jamestown
# Processing Record 28 of 625 | hasaki
# Processing Record 29 of 625 | storforshei
# Processing Record 30 of 625 | bongandanga
# Processing Record 31 of 625 | thompson
# Missing data in OpenWeatherAPI for mys shmidta
# Processing Record 33 of 625 | mancio lima
# Processing Record 34 of 625 | peniche
# Processing Record 35 of 625 | aquiraz
# Processing Record 36 of 625 | qaqortoq
# Processing Record 37 of 625 | ketchikan
# Processing Record 38 of 625 | hovd
# Processing Record 39 of 625 | makokou
# Processing Record 40 of 625 | vaini
# Processing Record 41 of 625 | ojinaga
# Processing Record 42 of 625 | westport
# Processing Record 43 of 625 | bredasdorp
# Processing Record 44 of 625 | haverfordwest
# Processing Record 45 of 625 | antalaha
# Processing Record 46 of 625 | new norfolk
# Processing Record 47 of 625 | umarkot
# Processing Record 48 of 625 | yining
# Processing Record 49 of 625 | albany
# Processing Record 50 of 625 | kavaratti
# Processing Record 51 of 625 | chunoyar
# Processing Record 52 of 625 | tabas
# Processing Record 53 of 625 | butaritari
# Missing data in OpenWeatherAPI for taolanaro
# Processing Record 55 of 625 | krapkowice
# Missing data in OpenWeatherAPI for barentsburg
# Processing Record 57 of 625 | upernavik
# Processing Record 58 of 625 | yanji
# Missing data in OpenWeatherAPI for louisbourg
# Processing Record 60 of 625 | leeton
# Processing Record 61 of 625 | tchibanga
# Processing Record 62 of 625 | inirida
# Processing Record 63 of 625 | hobart
# Processing Record 64 of 625 | saint-philippe
# Processing Record 65 of 625 | flinders
# Processing Record 66 of 625 | yellowknife
# Processing Record 67 of 625 | kapaa
# Processing Record 68 of 625 | anshun
# Processing Record 69 of 625 | la ronge
# Processing Record 70 of 625 | codrington
# Processing Record 71 of 625 | nanortalik
# Missing data in OpenWeatherAPI for sentyabrskiy
# Processing Record 73 of 625 | avarua
# Processing Record 74 of 625 | carnarvon
# Processing Record 75 of 625 | atuona
# Processing Record 76 of 625 | bonthe
# Processing Record 77 of 625 | souillac
# Processing Record 78 of 625 | ponta do sol
# Processing Record 79 of 625 | itarema
# Processing Record 80 of 625 | kjopsvik
# Missing data in OpenWeatherAPI for illoqqortoormiut
# Processing Record 82 of 625 | sibu
# Processing Record 83 of 625 | aitape
# Processing Record 84 of 625 | dikson
# Processing Record 85 of 625 | ken caryl
# Processing Record 86 of 625 | husavik
# Processing Record 87 of 625 | san vicente
# Processing Record 88 of 625 | puerto ayora
# Processing Record 89 of 625 | sao felix do xingu
# Missing data in OpenWeatherAPI for attawapiskat
# Processing Record 91 of 625 | thinadhoo
# Missing data in OpenWeatherAPI for yanan
# Processing Record 93 of 625 | grand gaube
# Processing Record 94 of 625 | general roca
# Processing Record 95 of 625 | tromso
# Processing Record 96 of 625 | alto piquiri
# Processing Record 97 of 625 | cherskiy
# Missing data in OpenWeatherAPI for bolungarvik
# Processing Record 99 of 625 | roald
# Processing Record 100 of 625 | urucui
# Processing Record 101 of 625 | east london
# Missing data in OpenWeatherAPI for nizhneyansk
# Processing Record 103 of 625 | hilo
# Processing Record 104 of 625 | fairbanks
# Processing Record 105 of 625 | dolores
# Processing Record 106 of 625 | porto murtinho
# Processing Record 107 of 625 | taltal
# Missing data in OpenWeatherAPI for mutsamudu
# Processing Record 109 of 625 | san cristobal
# Processing Record 110 of 625 | georgetown
# Processing Record 111 of 625 | ormara
# Processing Record 112 of 625 | muscatine
# Processing Record 113 of 625 | praya
# Missing data in OpenWeatherAPI for umzimvubu
# Processing Record 115 of 625 | plettenberg bay
# Processing Record 116 of 625 | portland
# Processing Record 117 of 625 | rio gallegos
# Processing Record 118 of 625 | coxim
# Processing Record 119 of 625 | lensk
# Processing Record 120 of 625 | kotturu
# Processing Record 121 of 625 | idil
# Processing Record 122 of 625 | khatanga
# Processing Record 123 of 625 | arraial do cabo
# Processing Record 124 of 625 | barrow
# Processing Record 125 of 625 | almaznyy
# Processing Record 126 of 625 | kasongo
# Processing Record 127 of 625 | karpogory
# Processing Record 128 of 625 | turukhansk
# Processing Record 129 of 625 | lebu
# Processing Record 130 of 625 | geraldton
# Processing Record 131 of 625 | nikel
# Processing Record 132 of 625 | pasighat
# Processing Record 133 of 625 | cairns
# Processing Record 134 of 625 | puerto leguizamo
# Missing data in OpenWeatherAPI for kamenskoye
# Processing Record 136 of 625 | noyabrsk
# Processing Record 137 of 625 | bonavista
# Processing Record 138 of 625 | hithadhoo
# Processing Record 139 of 625 | bonoua
# Processing Record 140 of 625 | simoes
# Processing Record 141 of 625 | yanam
# Processing Record 142 of 625 | port lincoln
# Missing data in OpenWeatherAPI for kazalinsk
# Processing Record 144 of 625 | guerrero negro
# Processing Record 145 of 625 | quatre cocos
# Missing data in OpenWeatherAPI for amderma
# Processing Record 147 of 625 | ribeira grande
# Processing Record 148 of 625 | talnakh
# Processing Record 149 of 625 | arlit
# Processing Record 150 of 625 | olafsvik
# Processing Record 151 of 625 | provideniya
# Missing data in OpenWeatherAPI for karaul
# Processing Record 153 of 625 | esperance
# Processing Record 154 of 625 | victoria
# Processing Record 155 of 625 | luderitz
# Processing Record 156 of 625 | college
# Processing Record 157 of 625 | clyde river
# Processing Record 158 of 625 | port hedland
# Processing Record 159 of 625 | srikakulam
# Processing Record 160 of 625 | sinnamary
# Processing Record 161 of 625 | abu samrah
# Processing Record 162 of 625 | masaguisi
# Processing Record 163 of 625 | ahipara
# Processing Record 164 of 625 | lagoa
# Processing Record 165 of 625 | turayf
# Processing Record 166 of 625 | palauig
# Processing Record 167 of 625 | half moon bay
# Processing Record 168 of 625 | zhigansk
# Processing Record 169 of 625 | peringat
# Processing Record 170 of 625 | goundam
# Processing Record 171 of 625 | puerto escondido
# Processing Record 172 of 625 | kavieng
# Processing Record 173 of 625 | berlevag
# Processing Record 174 of 625 | goya
# Processing Record 175 of 625 | mudgee
# Processing Record 176 of 625 | liwale
# Processing Record 177 of 625 | mahebourg
# Processing Record 178 of 625 | kodiak
# Processing Record 179 of 625 | bom jesus da lapa
# Processing Record 180 of 625 | am timan
# Processing Record 181 of 625 | dingle
# Processing Record 182 of 625 | manicore
# Processing Record 183 of 625 | vostok
# Processing Record 184 of 625 | palmer
# Processing Record 185 of 625 | rudarpur
# Processing Record 186 of 625 | bardiyah
# Processing Record 187 of 625 | mar del plata
# Processing Record 188 of 625 | bereda
# Processing Record 189 of 625 | maturin
# Processing Record 190 of 625 | aklavik
# Missing data in OpenWeatherAPI for belushya guba
# Processing Record 192 of 625 | cidreira
# Processing Record 193 of 625 | sabha
# Processing Record 194 of 625 | camacupa
# Processing Record 195 of 625 | dunedin
# Missing data in OpenWeatherAPI for ikole
# Processing Record 197 of 625 | severo-kurilsk
# Processing Record 198 of 625 | padang
# Processing Record 199 of 625 | kentville
# Processing Record 200 of 625 | petropavlovsk-kamchatskiy
# Processing Record 201 of 625 | nhulunbuy
# Processing Record 202 of 625 | paamiut
# Processing Record 203 of 625 | norman wells
# Processing Record 204 of 625 | clarence town
# Processing Record 205 of 625 | port alfred
# Processing Record 206 of 625 | smithers
# Processing Record 207 of 625 | ixtapa
# Processing Record 208 of 625 | mount isa
# Processing Record 209 of 625 | xiaolingwei
# Processing Record 210 of 625 | doka
# Processing Record 211 of 625 | lata
# Processing Record 212 of 625 | isangel
# Missing data in OpenWeatherAPI for listica
# Processing Record 214 of 625 | shasta lake
# Processing Record 215 of 625 | huron
# Processing Record 216 of 625 | donetsk
# Missing data in OpenWeatherAPI for sedelnikovo
# Processing Record 218 of 625 | chuy
# Processing Record 219 of 625 | tuktoyaktuk
# Processing Record 220 of 625 | bambous virieux
# Processing Record 221 of 625 | mitsamiouli
# Processing Record 222 of 625 | san quintin
# Processing Record 223 of 625 | hidalgotitlan
# Processing Record 224 of 625 | klaksvik
# Processing Record 225 of 625 | saint-ambroise
# Processing Record 226 of 625 | bethel
# Processing Record 227 of 625 | wyndham
# Processing Record 228 of 625 | sovetskaya gavan
# Processing Record 229 of 625 | praia da vitoria
# Processing Record 230 of 625 | acarau
# Processing Record 231 of 625 | kieta
# Processing Record 232 of 625 | namibe
# Processing Record 233 of 625 | necochea
# Processing Record 234 of 625 | taoudenni
# Processing Record 235 of 625 | chara
# Processing Record 236 of 625 | saint-pierre
# Processing Record 237 of 625 | los llanos de aridane
# Processing Record 238 of 625 | longyearbyen
# Processing Record 239 of 625 | manokwari
# Processing Record 240 of 625 | nikolskoye
# Processing Record 241 of 625 | iracoubo
# Processing Record 242 of 625 | bayir
# Processing Record 243 of 625 | port elizabeth
# Processing Record 244 of 625 | wanganui
# Processing Record 245 of 625 | male
# Processing Record 246 of 625 | matamoros
# Processing Record 247 of 625 | ostrovnoy
# Processing Record 248 of 625 | airai
# Processing Record 249 of 625 | praia
# Processing Record 250 of 625 | jumla
# Processing Record 251 of 625 | tasiilaq
# Processing Record 252 of 625 | ingham
# Processing Record 253 of 625 | mehamn
# Processing Record 254 of 625 | oktyabrskoye
# Processing Record 255 of 625 | sambava
# Processing Record 256 of 625 | ambon
# Processing Record 257 of 625 | khandyga
# Processing Record 258 of 625 | cockburn town
# Processing Record 259 of 625 | tak
# Processing Record 260 of 625 | castro
# Processing Record 261 of 625 | khulo
# Processing Record 262 of 625 | santa catarina de tepehuanes
# Processing Record 263 of 625 | katsuura
# Processing Record 264 of 625 | kyabe
# Processing Record 265 of 625 | brownsville
# Processing Record 266 of 625 | katobu
# Processing Record 267 of 625 | vao
# Missing data in OpenWeatherAPI for azrow
# Processing Record 269 of 625 | sidrolandia
# Processing Record 270 of 625 | kualakapuas
# Processing Record 271 of 625 | luwuk
# Processing Record 272 of 625 | ajdabiya
# Processing Record 273 of 625 | satellite beach
# Processing Record 274 of 625 | biak
# Processing Record 275 of 625 | hobyo
# Processing Record 276 of 625 | cabadiangan
# Processing Record 277 of 625 | iqaluit
# Processing Record 278 of 625 | chute-aux-outardes
# Processing Record 279 of 625 | axim
# Missing data in OpenWeatherAPI for bacuit
# Processing Record 281 of 625 | oriximina
# Processing Record 282 of 625 | kalmunai
# Processing Record 283 of 625 | vakhrushev
# Processing Record 284 of 625 | tumut
# Processing Record 285 of 625 | pangody
# Processing Record 286 of 625 | kahului
# Processing Record 287 of 625 | alofi
# Processing Record 288 of 625 | lichtenburg
# Processing Record 289 of 625 | salinopolis
# Processing Record 290 of 625 | nelson bay
# Processing Record 291 of 625 | faanui
# Processing Record 292 of 625 | hagerstown
# Processing Record 293 of 625 | pevek
# Processing Record 294 of 625 | port macquarie
# Processing Record 295 of 625 | baoshan
# Processing Record 296 of 625 | flin flon
# Processing Record 297 of 625 | velka bites
# Processing Record 298 of 625 | oudtshoorn
# Processing Record 299 of 625 | poum
# Processing Record 300 of 625 | chokurdakh
# Processing Record 301 of 625 | mumbwa
# Processing Record 302 of 625 | tshikapa
# Processing Record 303 of 625 | bajna
# Missing data in OpenWeatherAPI for dolbeau
# Processing Record 305 of 625 | abilene
# Processing Record 306 of 625 | ribeira brava
# Missing data in OpenWeatherAPI for vaitupu
# Processing Record 308 of 625 | barcelos
# Processing Record 309 of 625 | menongue
# Processing Record 310 of 625 | coquimbo
# Processing Record 311 of 625 | guaraniacu
# Processing Record 312 of 625 | cabo san lucas
# Processing Record 313 of 625 | bucerias
# Missing data in OpenWeatherAPI for tsihombe
# Processing Record 315 of 625 | tura
# Processing Record 316 of 625 | bagenalstown
# Processing Record 317 of 625 | mana
# Processing Record 318 of 625 | tuatapere
# Processing Record 319 of 625 | thanh hoa
# Processing Record 320 of 625 | lang son
# Processing Record 321 of 625 | bilma
# Missing data in OpenWeatherAPI for lolua
# Processing Record 323 of 625 | kimbe
# Missing data in OpenWeatherAPI for glubokoe
# Processing Record 325 of 625 | puri
# Processing Record 326 of 625 | coihaique
# Processing Record 327 of 625 | ukiah
# Processing Record 328 of 625 | mehnagar
# Processing Record 329 of 625 | saldanha
# Processing Record 330 of 625 | rawson
# Processing Record 331 of 625 | richards bay
# Missing data in OpenWeatherAPI for rawannawi
# Processing Record 333 of 625 | mayo
# Processing Record 334 of 625 | chipinge
# Processing Record 335 of 625 | avera
# Processing Record 336 of 625 | linxia
# Processing Record 337 of 625 | mandurah
# Missing data in OpenWeatherAPI for grand river south east
# Processing Record 339 of 625 | champerico
# Processing Record 340 of 625 | bushenyi
# Processing Record 341 of 625 | bezenchuk
# Missing data in OpenWeatherAPI for toliary
# Processing Record 343 of 625 | wad rawah
# Processing Record 344 of 625 | balabac
# Processing Record 345 of 625 | aswan
# Processing Record 346 of 625 | gari
# Processing Record 347 of 625 | powell river
# Processing Record 348 of 625 | lasa
# Processing Record 349 of 625 | takoradi
# Processing Record 350 of 625 | kalayaan
# Processing Record 351 of 625 | inhambane
# Missing data in OpenWeatherAPI for ust-kamchatsk
# Processing Record 353 of 625 | berdigestyakh
# Processing Record 354 of 625 | korla
# Processing Record 355 of 625 | miramar
# Processing Record 356 of 625 | port moresby
# Processing Record 357 of 625 | toktogul
# Processing Record 358 of 625 | homer
# Processing Record 359 of 625 | bozoum
# Processing Record 360 of 625 | san andres
# Processing Record 361 of 625 | green valley
# Missing data in OpenWeatherAPI for chugunash
# Processing Record 363 of 625 | tabou
# Processing Record 364 of 625 | mauboh
# Processing Record 365 of 625 | puerto quijarro
# Processing Record 366 of 625 | nouakchott
# Processing Record 367 of 625 | sarangani
# Processing Record 368 of 625 | nayagarh
# Processing Record 369 of 625 | hauterive
# Processing Record 370 of 625 | nizhniy tsasuchey
# Processing Record 371 of 625 | urengoy
# Processing Record 372 of 625 | nouadhibou
# Processing Record 373 of 625 | chegdomyn
# Processing Record 374 of 625 | peekskill
# Processing Record 375 of 625 | vrbas
# Processing Record 376 of 625 | goderich
# Processing Record 377 of 625 | hami
# Processing Record 378 of 625 | fairview
# Processing Record 379 of 625 | kaitangata
# Missing data in OpenWeatherAPI for tabiauea
# Processing Record 381 of 625 | marfino
# Processing Record 382 of 625 | tiksi
# Processing Record 383 of 625 | sitka
# Processing Record 384 of 625 | laguna
# Missing data in OpenWeatherAPI for nam tha
# Processing Record 386 of 625 | anloga
# Processing Record 387 of 625 | lavrentiya
# Processing Record 388 of 625 | kirakira
# Processing Record 389 of 625 | kapuskasing
# Processing Record 390 of 625 | marsa matruh
# Processing Record 391 of 625 | giddalur
# Missing data in OpenWeatherAPI for skagastrond
# Processing Record 393 of 625 | rabo de peixe
# Missing data in OpenWeatherAPI for longlac
# Processing Record 395 of 625 | pointe michel
# Processing Record 396 of 625 | dong hoi
# Processing Record 397 of 625 | alice springs
# Processing Record 398 of 625 | aksu
# Processing Record 399 of 625 | borogontsy
# Processing Record 400 of 625 | ambulu
# Processing Record 401 of 625 | cortez
# Processing Record 402 of 625 | kurchum
# Processing Record 403 of 625 | klyuchi
# Processing Record 404 of 625 | seguela
# Processing Record 405 of 625 | chernyshevskiy
# Processing Record 406 of 625 | bada
# Processing Record 407 of 625 | mackay
# Processing Record 408 of 625 | ahtopol
# Processing Record 409 of 625 | imbituba
# Processing Record 410 of 625 | naraina
# Processing Record 411 of 625 | togur
# Processing Record 412 of 625 | hualmay
# Missing data in OpenWeatherAPI for rungata
# Processing Record 414 of 625 | solwezi
# Processing Record 415 of 625 | yantzaza
# Processing Record 416 of 625 | barra
# Processing Record 417 of 625 | pestravka
# Processing Record 418 of 625 | penapolis
# Processing Record 419 of 625 | maryville
# Processing Record 420 of 625 | elko
# Processing Record 421 of 625 | ossora
# Processing Record 422 of 625 | kushima
# Processing Record 423 of 625 | tuy hoa
# Processing Record 424 of 625 | innisfail
# Processing Record 425 of 625 | komsomolskiy
# Processing Record 426 of 625 | almeirim
# Processing Record 427 of 625 | cabatuan
# Processing Record 428 of 625 | labytnangi
# Processing Record 429 of 625 | prince rupert
# Processing Record 430 of 625 | fremont
# Processing Record 431 of 625 | yarmouth
# Processing Record 432 of 625 | mae chan
# Processing Record 433 of 625 | kollam
# Processing Record 434 of 625 | leningradskiy
# Missing data in OpenWeatherAPI for palabuhanratu
# Processing Record 436 of 625 | emerald
# Processing Record 437 of 625 | atar
# Processing Record 438 of 625 | karratha
# Processing Record 439 of 625 | wad madani
# Processing Record 440 of 625 | maloy
# Processing Record 441 of 625 | ancud
# Missing data in OpenWeatherAPI for marcona
# Processing Record 443 of 625 | barra do garcas
# Processing Record 444 of 625 | malaut
# Processing Record 445 of 625 | merauke
# Missing data in OpenWeatherAPI for navabad
# Processing Record 447 of 625 | alenquer
# Processing Record 448 of 625 | novyy urengoy
# Processing Record 449 of 625 | vernon
# Processing Record 450 of 625 | bengkulu
# Processing Record 451 of 625 | savinka
# Processing Record 452 of 625 | ladan
# Processing Record 453 of 625 | kiryas joel
# Processing Record 454 of 625 | mujiayingzi
# Processing Record 455 of 625 | vuktyl
# Processing Record 456 of 625 | sampit
# Processing Record 457 of 625 | yantai
# Processing Record 458 of 625 | poshekhonye
# Processing Record 459 of 625 | opuwo
# Processing Record 460 of 625 | brae
# Processing Record 461 of 625 | wajima
# Processing Record 462 of 625 | asau
# Processing Record 463 of 625 | bagh
# Processing Record 464 of 625 | christchurch
# Processing Record 465 of 625 | henties bay
# Processing Record 466 of 625 | atambua
# Processing Record 467 of 625 | south sioux city
# Processing Record 468 of 625 | pinawa
# Processing Record 469 of 625 | verkhnyaya tura
# Processing Record 470 of 625 | hambantota
# Processing Record 471 of 625 | fortuna
# Processing Record 472 of 625 | alyangula
# Processing Record 473 of 625 | aguimes
# Processing Record 474 of 625 | vallenar
# Processing Record 475 of 625 | ucluelet
# Processing Record 476 of 625 | riberalta
# Processing Record 477 of 625 | marawi
# Processing Record 478 of 625 | gumdag
# Processing Record 479 of 625 | nuuk
# Processing Record 480 of 625 | shenjiamen
# Processing Record 481 of 625 | zhezkazgan
# Processing Record 482 of 625 | gisborne
# Processing Record 483 of 625 | mareeba
# Processing Record 484 of 625 | hyeres
# Processing Record 485 of 625 | cortes
# Processing Record 486 of 625 | marondera
# Processing Record 487 of 625 | chokwe
# Processing Record 488 of 625 | pathein
# Processing Record 489 of 625 | vulcan
# Processing Record 490 of 625 | sibolga
# Processing Record 491 of 625 | asfi
# Processing Record 492 of 625 | erenhot
# Processing Record 493 of 625 | lucapa
# Missing data in OpenWeatherAPI for zlatoustovsk
# Processing Record 495 of 625 | sexsmith
# Missing data in OpenWeatherAPI for lephepe
# Processing Record 497 of 625 | kaohsiung
# Processing Record 498 of 625 | deputatskiy
# Processing Record 499 of 625 | snezhnogorsk
# Processing Record 500 of 625 | friedrichshafen
# Processing Record 501 of 625 | ulaangom
# Processing Record 502 of 625 | krasnoselkup
# Processing Record 503 of 625 | urechesti
# Processing Record 504 of 625 | sobolevo
# Processing Record 505 of 625 | manakara
# Processing Record 506 of 625 | bongor
# Processing Record 507 of 625 | nyurba
# Processing Record 508 of 625 | mountain home
# Missing data in OpenWeatherAPI for kpagouda
# Missing data in OpenWeatherAPI for tumannyy
# Processing Record 511 of 625 | conceicao do araguaia
# Processing Record 512 of 625 | cartagena del chaira
# Processing Record 513 of 625 | anadyr
# Processing Record 514 of 625 | mangrol
# Processing Record 515 of 625 | sault sainte marie
# Processing Record 516 of 625 | sarab
# Processing Record 517 of 625 | faya
# Processing Record 518 of 625 | shimsk
# Processing Record 519 of 625 | tsiroanomandidy
# Processing Record 520 of 625 | sorland
# Processing Record 521 of 625 | owando
# Processing Record 522 of 625 | najran
# Processing Record 523 of 625 | vagay
# Processing Record 524 of 625 | guatire
# Processing Record 525 of 625 | road town
# Processing Record 526 of 625 | soe
# Processing Record 527 of 625 | upington
# Processing Record 528 of 625 | odweyne
# Processing Record 529 of 625 | constitucion
# Processing Record 530 of 625 | raton
# Processing Record 531 of 625 | tottori
# Processing Record 532 of 625 | dhadar
# Processing Record 533 of 625 | belyy yar
# Processing Record 534 of 625 | mao
# Processing Record 535 of 625 | gampaha
# Processing Record 536 of 625 | aden
# Processing Record 537 of 625 | aranos
# Processing Record 538 of 625 | daru
# Processing Record 539 of 625 | daoukro
# Missing data in OpenWeatherAPI for georgiu-dezh
# Processing Record 541 of 625 | lompoc
# Processing Record 542 of 625 | dubbo
# Processing Record 543 of 625 | yar-sale
# Processing Record 544 of 625 | nalut
# Processing Record 545 of 625 | leshukonskoye
# Processing Record 546 of 625 | san patricio
# Processing Record 547 of 625 | mecca
# Processing Record 548 of 625 | baruun-urt
# Processing Record 549 of 625 | adrar
# Processing Record 550 of 625 | tongren
# Processing Record 551 of 625 | pisco
# Processing Record 552 of 625 | angoche
# Processing Record 553 of 625 | meulaboh
# Processing Record 554 of 625 | roma
# Processing Record 555 of 625 | yerbogachen
# Processing Record 556 of 625 | saint-michel-des-saints
# Processing Record 557 of 625 | kurilsk
# Processing Record 558 of 625 | talcahuano
# Processing Record 559 of 625 | kato kamila
# Processing Record 560 of 625 | rocha
# Processing Record 561 of 625 | lanivtsi
# Processing Record 562 of 625 | kolda
# Processing Record 563 of 625 | domna
# Processing Record 564 of 625 | oyem
# Processing Record 565 of 625 | volta redonda
# Processing Record 566 of 625 | novikovo
# Processing Record 567 of 625 | nantucket
# Processing Record 568 of 625 | mubi
# Processing Record 569 of 625 | las palmas
# Processing Record 570 of 625 | chapais
# Processing Record 571 of 625 | kirovohrad
# Processing Record 572 of 625 | comodoro rivadavia
# Processing Record 573 of 625 | maamba
# Processing Record 574 of 625 | senador jose porfirio
# Processing Record 575 of 625 | kungurtug
# Missing data in OpenWeatherAPI for tubruq
# Processing Record 577 of 625 | palu
# Missing data in OpenWeatherAPI for artyk
# Processing Record 579 of 625 | koplik
# Processing Record 580 of 625 | cabedelo
# Missing data in OpenWeatherAPI for azimur
# Processing Record 582 of 625 | mogadishu
# Missing data in OpenWeatherAPI for wulanhaote
# Processing Record 584 of 625 | borgo san dalmazzo
# Processing Record 585 of 625 | aykhal
# Processing Record 586 of 625 | darhan
# Processing Record 587 of 625 | beloha
# Processing Record 588 of 625 | saurimo
# Processing Record 589 of 625 | gambela
# Processing Record 590 of 625 | odienne
# Processing Record 591 of 625 | glace bay
# Processing Record 592 of 625 | addanki
# Processing Record 593 of 625 | eureka
# Processing Record 594 of 625 | saint george
# Processing Record 595 of 625 | port blair
# Processing Record 596 of 625 | nizwa
# Processing Record 597 of 625 | elizabeth city
# Processing Record 598 of 625 | livramento
# Processing Record 599 of 625 | kindersley
# Processing Record 600 of 625 | luocheng
# Processing Record 601 of 625 | the valley
# Missing data in OpenWeatherAPI for dzhusaly
# Processing Record 603 of 625 | vardo
# Processing Record 604 of 625 | piacabucu
# Processing Record 605 of 625 | bubaque
# Processing Record 606 of 625 | teguise
# Processing Record 607 of 625 | maceio
# Processing Record 608 of 625 | caravelas
# Missing data in OpenWeatherAPI for mullaitivu
# Processing Record 610 of 625 | abu dhabi
# Processing Record 611 of 625 | yumen
# Processing Record 612 of 625 | casillas
# Processing Record 613 of 625 | aloleng
# Processing Record 614 of 625 | katete
# Processing Record 615 of 625 | sahuaripa
# Processing Record 616 of 625 | hofn
# Processing Record 617 of 625 | riyadh
# Processing Record 618 of 625 | malumfashi
# Processing Record 619 of 625 | kasongo-lunda
# Processing Record 620 of 625 | viedma
# Processing Record 621 of 625 | urumqi
# Processing Record 622 of 625 | nome
# Processing Record 623 of 625 | palafrugell
# Processing Record 624 of 625 | cerqueira cesar
#              City  Latitude  Longitude  Temperature  Humidity  Wind Speed  \
# 0         Qaanaaq     77.48     -69.36        -7.56        71        7.31
# 1         Mataura    -46.19     168.86        55.99        74        8.01
# 2       Busselton    -33.65     115.33        58.64        85        5.01
# 3       Wonthaggi    -38.60     145.59        75.25        63       10.65
# 4         Wanning     18.80     110.40        76.95        71       19.80
# 5     Pangnirtung     66.15     -65.71         7.32        81        4.63
# 6  Saint-Augustin     51.23     -58.65        28.81        75        7.65
# 7    Punta Arenas    -53.15     -70.92        41.00        75       17.22
# 8       Cape Town    -33.93      18.42        57.85        47        3.36
# 9         Rikitea    -23.12    -134.97        72.79        77       17.38
#
#    Cloudiness
# 0           1
# 1          92
# 2          98
# 3          28
# 4          86
# 5          18
# 6          99
# 7           0
# 8          20
# 9          32

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df.to_csv(output_data_file, index=False)

# %%
df
# Out:
#           City  Latitude  Longitude  Temperature  Humidity  Wind Speed  \
# 0      Ushuaia    -54.80     -68.30        39.20        92       17.22
# 1         Lebu    -37.62     -73.65        51.46        92       17.16
# 2       Bethel     41.37     -73.41        45.79        93        2.01
# 3       Barrow     71.29    -156.79        15.80        78       25.28
# 4    Hithadhoo     -0.60      73.08        84.40        71        8.95
# ..         ...       ...        ...          ...       ...         ...
# 547     Kailua     21.40    -157.74        78.35        65       11.41
# 548  Sinnamary      5.38     -52.95        77.97        83       12.24
# 549       Meru      0.05      37.66        63.07        88        2.51
# 550    Wanning     18.80     110.40        76.95        71       21.14
# 551  Maniitsoq     65.42     -52.90        20.86        86       31.27
#
#      Cloudiness
# 0            75
# 1            54
# 2             1
# 3            90
# 4            21
# ..          ...
# 547          75
# 548           4
# 549          93
# 550          67
# 551         100
#
# [552 rows x 7 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
